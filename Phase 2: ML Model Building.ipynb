# %% [markdown]
# ## Phase 2: ML Building
#
# In Phase 1, we completed the EDA step allowing us to understand the different features of the dataset we are working with and performed some pre-processing of the data. Now we want to use the pre-processed X and Y data to start training the ML Classifier model.

# %%
import pandas as pd

X = pd.read_csv("/content/X_data")
Y = pd.read_csv("/content/Y_data")

print(X.head())
print(Y.head())
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.521037  0.022658  0.545989  0.363733  0.593753  0.792037  0.703140
# 1  0.643144  0.272574  0.615783  0.501591  0.289880  0.181768  0.203608
# 2  0.601496  0.390260  0.595743  0.449417  0.514309  0.431017  0.462512
# 3  0.210090  0.360839  0.233501  0.102906  0.811321  0.811361  0.565604
# 4  0.629893  0.156578  0.630986  0.489290  0.430351  0.347893  0.463918
#
#           7         8         9  ...        20        21        22        23  \
# 0  0.731113  0.686364  0.605518  ...  0.620776  0.141525  0.668310  0.450698
# 1  0.348757  0.379798  0.141323  ...  0.606901  0.303571  0.539818  0.435214
# 2  0.635686  0.509596  0.211247  ...  0.556386  0.360075  0.508442  0.374508
# 3  0.522863  0.776263  1.000000  ...  0.248310  0.385928  0.241347  0.094008
# 4  0.518390  0.378283  0.186816  ...  0.519744  0.123934  0.506948  0.341575
#
#          24        25        26        27        28        29
# 0  0.601136  0.619292  0.568610  0.912027  0.598462  0.418864
# 1  0.347553  0.154563  0.192971  0.639175  0.233590  0.222878
# 2  0.483590  0.385375  0.359744  0.835052  0.403706  0.213433
# 3  0.915472  0.814012  0.548642  0.884880  1.000000  0.773711
# 4  0.437364  0.172415  0.319489  0.558419  0.157500  0.142595
#
# [5 rows x 30 columns]
#    0
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %% [markdown]
# We are going to split the data into training and testing data for the ML Classifier model.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)
print("Shape of training data is: ", X_train.shape)
print("Shape of testing data is: ", X_test.shape)
# Out:
# Shape of training data is:  (426, 30)
# Shape of testing data is:  (143, 30)

# %% [markdown]
# We are going to use the keras library because of its ease for building and training neural networks.
#
# Specifically in this case, we will be using the Sequential API to build the neural network. Using a linear stack of layers we can build the neural network.

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Activation, Dropout

# %% [markdown]
# Here, we first add a dense hidden layer with 16 nodes and 30 input points per sample from the first layer. We also define a dropout of 20% of the node connections between the first and dense layer, randomly. Then we add the output dense layer with 1 node and calculated based on the sigmoid activation function.

# %%
model = Sequential([
    Input(shape =(30,)),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
    ])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 16)                  │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# We will now train our model and display each epoch. Here we have 100 epochs or training passes. At the end of each training pass, the model evaluates using the validation data from X_test and y_test, which helps monitor overfitting and accuracy.

# %%
history = model.fit(X_train, y_train, batch_size=64, epochs=100, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5054 - loss: 0.6314 - val_accuracy: 0.5664 - val_loss: 0.6167
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5551 - loss: 0.6481 - val_accuracy: 0.6573 - val_loss: 0.6027
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6233 - loss: 0.6294 - val_accuracy: 0.7552 - val_loss: 0.5887
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7447 - loss: 0.5987 - val_accuracy: 0.8182 - val_loss: 0.5748
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9132 - loss: 0.2032 - val_accuracy: 0.9580 - val_loss: 0.1614
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9188 - loss: 0.2116 - val_accuracy: 0.9580 - val_loss: 0.1607
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9342 - loss: 0.1872 - val_accuracy: 0.9580 - val_loss: 0.1586
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9332 - loss: 0.2067 - val_accuracy: 0.9580 - val_loss: 0.1572
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9214 - loss: 0.2085 - val_accuracy: 0.9580 - val_loss: 0.1561
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9283 - loss: 0.2035 - val_accuracy: 0.9580 - val_loss: 0.1545
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9174 - loss: 0.2044 - val_accuracy: 0.9580 - val_loss: 0.1529
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9358 - loss: 0.1840 - val_accuracy: 0.9650 - val_loss: 0.1505
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9122 - loss: 0.2327 - val_accuracy: 0.9580 - val_loss: 0.1497
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9149 - loss: 0.2143 - val_accuracy: 0.9650 - val_loss: 0.1502
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9232 - loss: 0.2160 - val_accuracy: 0.9650 - val_loss: 0.1479
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9363 - loss: 0.1882 - val_accuracy: 0.9650 - val_loss: 0.1460
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9072 - loss: 0.2134 - val_accuracy: 0.9720 - val_loss: 0.1454
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9234 - loss: 0.1990 - val_accuracy: 0.9720 - val_loss: 0.1435
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9351 - loss: 0.1899 - val_accuracy: 0.9720 - val_loss: 0.1418
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9509 - loss: 0.1816 - val_accuracy: 0.9720 - val_loss: 0.1411
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9437 - loss: 0.1673 - val_accuracy: 0.9650 - val_loss: 0.1402
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9419 - loss: 0.1927 - val_accuracy: 0.9720 - val_loss: 0.1385
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9294 - loss: 0.1923 - val_accuracy: 0.9720 - val_loss: 0.1376
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9492 - loss: 0.1804 - val_accuracy: 0.9650 - val_loss: 0.1372
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9225 - loss: 0.2003 - val_accuracy: 0.9650 - val_loss: 0.1360
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9322 - loss: 0.1799 - val_accuracy: 0.9720 - val_loss: 0.1343
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9358 - loss: 0.1892 - val_accuracy: 0.9720 - val_loss: 0.1328
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9202 - loss: 0.1908 - val_accuracy: 0.9650 - val_loss: 0.1330
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9346 - loss: 0.1778 - val_accuracy: 0.9650 - val_loss: 0.1341
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9423 - loss: 0.1665 - val_accuracy: 0.9650 - val_loss: 0.1337
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9344 - loss: 0.1637 - val_accuracy: 0.9650 - val_loss: 0.1306

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Here we will display the training/validation loss and training/validation accuracy as 2 separate plots to understand the model performance.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']  #Use accuracy if acc doesn't work
val_acc = history.history['val_accuracy']  #Use val_accuracy if acc doesn't work
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Using the confusion matrix, we can understand the true accuracy of the model; expecially in binary decisions. This matrix allows us to see how many true positives and negatives the model makes when using the testing data set.

# %%
# Predicting the Test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d8965437ce0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d8965437ce0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# <Axes: >

# %% [markdown]
# As we can see that the accuracy is quite high. Of the 91 'true' benign tumor cases, the model was able to correctly classify 88 of those cases as benign. Of the 52 'true' malignant tumor cases, the model was able to correctly classify 51 of those cases as malignant. Giving us an accuracy of at least 95% for both cases.
